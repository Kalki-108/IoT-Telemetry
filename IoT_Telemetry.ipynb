# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
# loading the diabetes dataset to a pandas DataFrame
iot_telemetry_dataset = pd.read_csv('/content/iot_telemetry_data.csv')

# %%
 pd.read_csv?

# %%
# printing the first 5 rows of the dataset
iot_telemetry_dataset.head()
# Out:
#              ts             device        co   humidity  light       lpg  \
# 0  1.594512e+09  b8:27:eb:bf:9d:51  0.004956  51.000000  False  0.007651
# 1  1.594512e+09  00:0f:00:70:91:0a  0.002840  76.000000  False  0.005114
# 2  1.594512e+09  b8:27:eb:bf:9d:51  0.004976  50.900000  False  0.007673
# 3  1.594512e+09  1c:bf:ce:15:ec:4d  0.004403  76.800003   True  0.007023
# 4  1.594512e+09  b8:27:eb:bf:9d:51  0.004967  50.900000  False  0.007664
#
#    motion     smoke       temp
# 0   False  0.020411  22.700000
# 1   False  0.013275  19.700001
# 2   False  0.020475  22.600000
# 3   False  0.018628  27.000000
# 4   False  0.020448  22.600000

# %%
# number of rows and Columns in this dataset
iot_telemetry_dataset.shape
# Out:
# (405184, 9)

# %%
# getting the statistical measures of the data
iot_telemetry_dataset.describe()
# Out:
#                  ts             co       humidity            lpg  \
# count  4.051840e+05  405184.000000  405184.000000  405184.000000
# mean   1.594858e+09       0.004639      60.511694       0.007237
# std    1.994984e+05       0.001250      11.366489       0.001444
# min    1.594512e+09       0.001171       1.100000       0.002693
# 25%    1.594686e+09       0.003919      51.000000       0.006456
# 50%    1.594858e+09       0.004812      54.900000       0.007489
# 75%    1.595031e+09       0.005409      74.300003       0.008150
# max    1.595203e+09       0.014420      99.900002       0.016567
#
#                smoke           temp
# count  405184.000000  405184.000000
# mean        0.019264      22.453987
# std         0.004086       2.698347
# min         0.006692       0.000000
# 25%         0.017024      19.900000
# 50%         0.019950      22.200000
# 75%         0.021838      23.600000
# max         0.046590      30.600000

# %% [markdown]
# Data Standardization

# %%
scaler = StandardScaler()

# %%
X = iot_telemetry_dataset.drop(columns = 'device', axis=1)
Y = iot_telemetry_dataset['device']

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
standardized_data = scaler.transform(X)

# %%
print(standardized_data)
# Out:
# [[-1.73396548  0.25367019 -0.83682    ... -0.03451086  0.28086716
#    0.09117173]
#  [-1.73396373 -1.43897634  1.3626305  ... -0.03451086 -1.46563677
#   -1.02062115]
#  [-1.733947    0.26972883 -0.84561781 ... -0.03451086  0.29649455
#    0.05411196]
#  ...
#  [ 1.73133869 -0.07870475  1.33623683 ... -0.03451086 -0.04592439
#    1.53650299]
#  [ 1.73134276 -0.71535911  1.30104616 ... -0.03451086 -0.69182106
#   -1.20592002]
#  [ 1.73134419  1.02048968 -1.06556286 ... -0.03451086  1.0122022
#   -0.09412713]]

# %%
X = standardized_data
Y = iot_telemetry_dataset['device']

# %%
print(X)
print(Y)
# Out:
# [[-1.73396548  0.25367019 -0.83682    ... -0.03451086  0.28086716
#    0.09117173]
#  [-1.73396373 -1.43897634  1.3626305  ... -0.03451086 -1.46563677
#   -1.02062115]
#  [-1.733947    0.26972883 -0.84561781 ... -0.03451086  0.29649455
#    0.05411196]
#  ...
#  [ 1.73133869 -0.07870475  1.33623683 ... -0.03451086 -0.04592439
#    1.53650299]
#  [ 1.73134276 -0.71535911  1.30104616 ... -0.03451086 -0.69182106
#   -1.20592002]
#  [ 1.73134419  1.02048968 -1.06556286 ... -0.03451086  1.0122022
#   -0.09412713]]
# 0         b8:27:eb:bf:9d:51
# 1         00:0f:00:70:91:0a
# 2         b8:27:eb:bf:9d:51
# 3         1c:bf:ce:15:ec:4d
# 4         b8:27:eb:bf:9d:51
#                 ...
# 405179    00:0f:00:70:91:0a
# 405180    b8:27:eb:bf:9d:51
# 405181    1c:bf:ce:15:ec:4d
# 405182    00:0f:00:70:91:0a
# 405183    b8:27:eb:bf:9d:51
# Name: device, Length: 405184, dtype: object
